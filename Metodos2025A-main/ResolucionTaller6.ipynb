# %% [markdown]
# # Taller 6 - Metodos Numéricos
#
# - **Nombre:** Joshua Daniel Menendez Farias

# %%
# %load_ext autoreload
# Out:
# [06-24 21:39:31][INFO] 2025-06-24 21:39:31.476718
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
'''
Es importante aclarar que para la resolucion de este taller lo que se hizo fue modificar el codigo
de ambas funciones para que no imprima los cambios en cada iteracion, gracias a esto se pudo probar
ambas funciones con ecuaciones de hasta 500 variables y 500 ecuaciones sin que se colgara el kernel 
de jupyter.
'''

# %autoreload 2
from src import comparar_tiempos

comparar_tiempos(500)

# %% [markdown]
# Finalmente, al observar el resultado, se puede ver que el metodo gausiano ocupa menos tiempo que el metodo de gauss-jordan, lo que **indica que el metodo gausiano es mas eficiente**. Aunque hay que hacer calculos adicionales para obtener los valores de cada variable, el tiempo de ejecucion es menor que el metodo de gauss-jordan.
